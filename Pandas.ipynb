# %% [markdown]
# <a href="https://colab.research.google.com/github/AJuliPS/AI2023-2_JulianaPonce/blob/main/Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **LIBRERIA PANDAS**

# %%
import pandas as pdjuli

# %%
tmp=pdjuli.Series(data=[100,200,300,400],index=['angie','juliana', 'nazli','sofia'])
print(tmp)
# Out:
# angie      100
# juliana    200
# nazli      300
# sofia      400
# dtype: int64

# %%
tmp.shape
# Out:
# (4,)

# %%
print(tmp['nazli'])

print(tmp[-2])
# Out:
# 300
# 300

# %%
tmp*2
# Out:
# angie      200
# juliana    400
# nazli      600
# sofia      800
# dtype: int64

# %%
print(tmp[[1,2,3]])
# Out:
# juliana    200
# nazli      300
# sofia      400
# dtype: int64

# %%
tmp.index
# Out:
# Index(['angie', 'juliana', 'nazli', 'sofia'], dtype='object')

# %% [markdown]
# **DATAFRAME**

# %%
diccionario = {"nombre": "Juan","edad": 30,"ciudad": "Quito"}

# %%
aux={'uno':pdjuli.Series([1,2,3],index=['durazno','camisa','teclado']),
     'dos':pdjuli.Series([10,20,30],index=['mora','uva','mamey'])}

# %%
aux
# Out:
# {'uno': durazno    1
#  camisa     2
#  teclado    3
#  dtype: int64,
#  'dos': mora     10
#  uva      20
#  mamey    30
#  dtype: int64}

# %%
df=pdjuli.DataFrame(aux)

# %%
df.shape
# Out:
# (6, 2)

# %%
df
# Out:
#          uno   dos
# camisa   2.0   NaN
# durazno  1.0   NaN
# mamey    NaN  30.0
# mora     NaN  10.0
# teclado  3.0   NaN
# uva      NaN  20.0

# %%
df.index
# Out:
# Index(['camisa', 'durazno', 'mamey', 'mora', 'teclado', 'uva'], dtype='object')

# %%
df.columns
# Out:
# Index(['uno', 'dos'], dtype='object')

# %%
df['tres']=df['uno']*df['dos']

# %%
df
# Out:
#           uno   dos   tres
# camisa    NaN   NaN    NaN
# durazno   NaN   NaN    NaN
# mamey    30.0  30.0  900.0
# mora     10.0  10.0  100.0
# teclado   NaN   NaN    NaN
# uva      20.0  20.0  400.0

# %%
df['cuatro']=df['uno']+df['dos']
df
# Out:
#           uno   dos  tres  cuatro
# camisa    NaN   NaN   NaN     NaN
# durazno   NaN   NaN   NaN     NaN
# mamey    30.0  30.0  60.0    60.0
# mora     10.0  10.0  20.0    20.0
# teclado   NaN   NaN   NaN     NaN
# uva      20.0  20.0  40.0    40.0

# %%
df['filtro']=df['uno']>2
df
# Out:
#           uno   dos  filtro
# camisa    NaN   NaN   False
# durazno   NaN   NaN   False
# mamey    30.0  30.0    True
# mora     10.0  10.0    True
# teclado   NaN   NaN   False
# uva      20.0  20.0    True

# %%
del df['tres']
df
# Out:
#           uno   dos  cuatro  filtro
# camisa    NaN   NaN     NaN   False
# durazno   NaN   NaN     NaN   False
# mamey    30.0  30.0    60.0    True
# mora     10.0  10.0    20.0    True
# teclado   NaN   NaN     NaN   False
# uva      20.0  20.0    40.0    True

# %%
del df['filtro']

df2=df.pop('cuatro')

# %%
df
# Out:
#           uno   dos
# camisa    NaN   NaN
# durazno   NaN   NaN
# mamey    30.0  30.0
# mora     10.0  10.0
# teclado   NaN   NaN
# uva      20.0  20.0

# %% [markdown]
# **CASO DE ESTUDIO**

# %%
tags=pdjuli.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/tags.csv')
ratings=pdjuli.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/ratings01.csv')
movies = pdjuli.read_csv('https://raw.githubusercontent.com/ChicagoBoothML/DATA___MovieLens___20M/master/movies.csv')

# %%
tags.shape
# Out:
# (465564, 4)

# %%
tags.columns
# Out:
# Index(['userId', 'movieId', 'tag', 'timestamp'], dtype='object')

# %%
tags[:10]
# Out:
#    userId  movieId               tag   timestamp
# 0      18     4141       Mark Waters  1240597180
# 1      65      208         dark hero  1368150078
# 2      65      353         dark hero  1368150079
# 3      65      521     noir thriller  1368149983
# 4      65      592         dark hero  1368150078
# 5      65      668         bollywood  1368149876
# 6      65      898  screwball comedy  1368150160
# 7      65     1248     noir thriller  1368149983
# 8      65     1391              mars  1368150055
# 9      65     1617          neo-noir  1368150217

# %%
print(tags['tag'][:10])
# Out:
# 0         Mark Waters
# 1           dark hero
# 2           dark hero
# 3       noir thriller
# 4           dark hero
# 5           bollywood
# 6    screwball comedy
# 7       noir thriller
# 8                mars
# 9            neo-noir
# Name: tag, dtype: object

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
tags.head(10) #HEAD imprime un nro de muestras
# Out:
#    userId  movieId               tag   timestamp
# 0      18     4141       Mark Waters  1240597180
# 1      65      208         dark hero  1368150078
# 2      65      353         dark hero  1368150079
# 3      65      521     noir thriller  1368149983
# 4      65      592         dark hero  1368150078
# 5      65      668         bollywood  1368149876
# 6      65      898  screwball comedy  1368150160
# 7      65     1248     noir thriller  1368149983
# 8      65     1391              mars  1368150055
# 9      65     1617          neo-noir  1368150217

# %%
ratings.head(10)
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580
# 5       1      112     3.5  1094785740
# 6       1      151     4.0  1094785734
# 7       1      223     4.0  1112485573
# 8       1      253     4.0  1112484940
# 9       1      260     4.0  1112484826

# %%
ratings.tail(10)
# Out:
#          userId  movieId  rating   timestamp
# 1999990   13567    54004     3.5  1262994633
# 1999991   13567    58154     4.0  1262994642
# 1999992   13567    58559     5.0  1262994213
# 1999993   13567    59333     3.5  1262994526
# 1999994   13567    59369     4.0  1262764264
# 1999995   13567    59725     3.5  1262994714
# 1999996   13567    63062     5.0  1262764337
# 1999997   13567    64957     5.0  1262764172
# 1999998   13567    65216     4.5  1262994367
# 1999999   13567    66203     4.0  1262994418

# %% [markdown]
# **CLASE 2 - 22/11/2023**

# %%
movies='/content/set_datos/movies.csv'
tags='/content/set_datos/tags.csv'
ratings='/content/set_datos/ratings.csv'

# %%
movies=pdjuli.read_csv(movies)
tags=pdjuli.read_csv(tags)
ratings=pdjuli.read_csv(ratings)

movies.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
tags.head(3)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224

# %%
ratings.shape
# Out:
# (100836, 4)

# %%
movies.shape
# Out:
# (9742, 3)

# %%
tags.shape
# Out:
# (3683, 4)

# %%
ratings.columns #Ver caracteristicas
# Out:
# Index(['userId', 'movieId', 'rating', 'timestamp'], dtype='object')

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
tags.head(5)
# Out:
#    userId  movieId              tag
# 0       2    60756            funny
# 1       2    60756  Highly quotable
# 2       2    60756     will ferrell
# 3       2    89774     Boxing story
# 4       2    89774              MMA

# %%
ratings.head(5)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %%
ratings.head(10)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0
# 5       1       70     3.0
# 6       1      101     5.0
# 7       1      110     4.0
# 8       1      151     5.0
# 9       1      157     5.0

# %%
ratings.iloc[6] #iloc es para imprimir
# Out:
# userId       1.0
# movieId    101.0
# rating       5.0
# Name: 6, dtype: float64

# %%
print(ratings.iloc[[30, 40, 50]]) #Imprimir filas de un set de datos
# Out:
#     userId  movieId  rating
# 30       1      552     4.0
# 40       1      733     4.0
# 50       1     1023     5.0

# %%
ratings.head(3)
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0

# %%
ratings.describe()
# Out:
#               userId        movieId         rating
# count  100836.000000  100836.000000  100836.000000
# mean      326.127564   19435.295718       3.501557
# std       182.618491   35530.987199       1.042529
# min         1.000000       1.000000       0.500000
# 25%       177.000000    1199.000000       3.000000
# 50%       325.000000    2991.000000       3.500000
# 75%       477.000000    8122.000000       4.000000
# max       610.000000  193609.000000       5.000000

# %%
ratings.shape
# Out:
# (100836, 3)

# %%
print(ratings['rating'].min())
# Out:
# 0.5

# %%
print(ratings['rating'].max())
# Out:
# 5.0

# %%
print(ratings['rating'].std())
# Out:
# 1.042529239060635

# %%
print(ratings['rating'].mean())
# Out:
# 3.501556983616962

# %%
ratings.corr() #Correlacional
# Out:
#            userId   movieId    rating
# userId   1.000000  0.006773 -0.049348
# movieId  0.006773  1.000000 -0.004061
# rating  -0.049348 -0.004061  1.000000

# %%
filter=ratings['rating']>5

# %%
filter.any()
# Out:
# False

# %%
filter=ratings['rating']>0

# %%
filter.any()
# Out:
# True

# %%
mask=ratings['rating']>3

# %%
print(mask.any())
# Out:
# True

# %%
aux=ratings[mask]
print(aux.shape)

print(aux.head(3))
# Out:
# (61716, 3)
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
ratings.isnull().any()
# Out:
# userId     False
# movieId    False
# rating     False
# dtype: bool

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag        False
# dtype: bool

# %%
ratings.hist(column='rating',figsize=[10,7])
# Out:
# array([[<Axes: title={'center': 'rating'}>]], dtype=object)

# %%
ratings.shape
# Out:
# (100836, 3)

# %%
tags.head(10)
# Out:
#    userId  movieId                tag
# 0       2    60756              funny
# 1       2    60756    Highly quotable
# 2       2    60756       will ferrell
# 3       2    89774       Boxing story
# 4       2    89774                MMA
# 5       2    89774          Tom Hardy
# 6       2   106782              drugs
# 7       2   106782  Leonardo DiCaprio
# 8       2   106782    Martin Scorsese
# 9       7    48516       way too long

# %%
tags.hist(column='movieId',figsize=[9,4])
# Out:
# array([[<Axes: title={'center': 'movieId'}>]], dtype=object)

# %%
movies.columns
# Out:
# Index(['movieId', 'title', 'genres'], dtype='object')

# %%
movies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
is_animation=movies['genres'].str.contains('Animation')

# %%
newMovies=movies[is_animation]

# %%
newMovies.head(10)
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
# 5        6                         Heat (1995)
# 6        7                      Sabrina (1995)
# 7        8                 Tom and Huck (1995)
# 8        9                 Sudden Death (1995)
# 9       10                    GoldenEye (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy
# 5                        Action|Crime|Thriller
# 6                               Comedy|Romance
# 7                           Adventure|Children
# ...

# %%
tags='/content/set_datos/tags.csv'
tags=pdjuli.read_csv(tags)

# %%
tags.head(5)
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
tags['informationDateTime']=pdjuli.to_datetime(tags['timestamp'],unit='s')

# %%
tags.head(10)
# Out:
#    userId  movieId                tag   timestamp informationDateTime
# 0       2    60756              funny  1445714994 2015-10-24 19:29:54
# 1       2    60756    Highly quotable  1445714996 2015-10-24 19:29:56
# 2       2    60756       will ferrell  1445714992 2015-10-24 19:29:52
# 3       2    89774       Boxing story  1445715207 2015-10-24 19:33:27
# 4       2    89774                MMA  1445715200 2015-10-24 19:33:20
# 5       2    89774          Tom Hardy  1445715205 2015-10-24 19:33:25
# 6       2   106782              drugs  1445715054 2015-10-24 19:30:54
# 7       2   106782  Leonardo DiCaprio  1445715051 2015-10-24 19:30:51
# 8       2   106782    Martin Scorsese  1445715056 2015-10-24 19:30:56
# 9       7    48516       way too long  1169687325 2007-01-25 01:08:45
